# %% [markdown]
# # High content imaging screen clustering
#
# This notebook records progress in the Marcelle HCS image clustering project.
#
# As always, we start by setting matplotlib inline and importing pyplot.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# Next, we set the working directory...

# %%
import os
working_dir = '~/Data/marcelle-hcs-sample/features'
os.chdir(os.path.expanduser(working_dir))

# %% [markdown]
# # Set up file mapping
#
# The working directory contains a pre-populated file called `dirs.txt` that contains all the directories on the merri cluster in which a feature map was created. (As well as the RGB images.) We use this to copy over each feature matrix.

# %%
import subprocess as sp
import time

with open('dirs.txt', 'r') as fin:
    line = fin.readline().rstrip()
    dirs = line.split(' ')
    
from husc.screens import myofusion as myo
reload(myo)

remote_base_dir = 'marcelle/raw-data'

plateids = map(myo.dir2plate, dirs)
feature_fns = ['features-%i.h5' % p for p in plateids]
#for d, f in zip(dirs, feature_fns):
#    if not os.path.exists(f):
#        time.sleep(10) # merri appears to choke with too many scps
#        sp.check_call(['scp', 'jni@merri.vlsci.unimelb.edu.au:' +
#                 os.path.join(remote_base_dir, d, 'features.h5'), f])
# Out:
# Plate ID NOCODE cannot be converted to int, replaced with 0.
# Plate ID NOCODE cannot be converted to int, replaced with 0.

# %% [markdown]
# The above only needs to be run once, so we store the run code here:
#
# ```python
# for d, f in zip(dirs, feature_fns):
#     if not os.path.exists(f): # allow resumption of interrupted scps
#         time.sleep(10) # merri appears to choke with too many scps
#         sp.check_call(['scp', 'jni@merri.vlsci.unimelb.edu.au:' +
#                  os.path.join(remote_base_dir, d, 'features.h5'), f])
# ```
#
# Let's do a sanity check to ensure plate ids are unique:

# %%
print (len(dirs), len(set(dirs)),
       len(plateids), len(set(plateids)))
tempdict = {}
for k in plateids:
    tempdict.setdefault(k, []).append(k)
print([k for k, v in tempdict.items() if len(v) > 1])
# Out:
# (186, 186, 186, 185)
# [0]

# %% [markdown]
# # Data input
#
# Next, we read in all the feature maps using `pandas`.

# %%
import os
import pandas as pd
import numpy as np

# %%
h5_fns = sorted(filter(lambda s: s.startswith('feature-') and
                       s.endswith('.h5') and not
                       s.endswith('NOCODE.h5'), os.listdir('.')))
datasets = [pd.read_hdf(f, 'data') for f in h5_fns]

# %%
data = pd.concat(datasets)
print(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1680 entries, /scratch/merri/jobs/1489812/MYORES-p1-j01-110210_02490688_53caa10e-ac15-4166-9b9d-4b1167f3b9c6_C03_w1_stitched.chs.tif to /scratch/merri/jobs/1489829/MYORES-p1-j01-110210_02490705_b2c8bbb1-f56f-4e20-b344-b31536523085_N22_w1_stitched.chs.tif
# Columns: 291 entries, mcf-otsu-threshold-num-objs to adapt-cells-with-11-nuclei
# dtypes: float64(291)
# /Users/nuneziglesiasj/venv/husc/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)

# %% [markdown]
# # Initial exploratory analysis
#
# Now, let's use scikit-learn to do some PCA.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import decomposition

# %%
X = StandardScaler().fit_transform(data)
pca = decomposition.PCA().fit(X)
pca.n_components = 2
X_reduced = pca.fit_transform(X)
print(X_reduced.shape)
# Out:
# (1680, 2)

# %% [markdown]
# The obligatory PCA scatter:

# %%
plt.scatter(*(X_reduced.T))

# %% [markdown]
# What features contributed most to the two top PCA components?

# %%
pca_comp1, pca_comp2 = (np.argsort(pca.components_[0])[-1:-4:-1],
                        np.argsort(pca.components_[1])[-1:-4:-1])
data.columns[pca_comp1], data.columns[pca_comp2]
# Out:
# (Index([u'nuclei-d-neighbor-1--percentile-95', u'nuclei-d-neighbor-2--percentile-5', u'nuclei-d-neighbor-2--percentile-25'], dtype=object),
#  Index([u'cells-adaptive-threshold-num-objs', u'cells-otsu-threshold-num-objs', u'mcf-otsu-threshold-MaxIntensity-percentile25'], dtype=object))

# %% [markdown]
# # Clustering
#
# Let's cluster the data (using KMeans):

# %%
from sklearn import cluster

# %%
# average cluster size of 10
avg_cluster_size = 20
K = cluster.MiniBatchKMeans(n_clusters=(X.shape[0] // avg_cluster_size))
K = K.fit(X)

# %% [markdown]
# # Mapping data rows to genes and images
#
# Now, we can find out which images clustered together and which interfering RNAs they correspond to.

# %%
from husc import preprocess as pre
reload(pre)
myores_semantic_filename = myo.myores_semantic_filename

# %%
plate2dir = myo.make_plate2dir_dict(dirs)
# Out:
# Plate ID NOCODE cannot be converted to int, replaced with 0.
# Plate ID NOCODE cannot be converted to int, replaced with 0.

# %%
filepaths = [myo.scratch2real(fn, plate2dir) for fn in data.index]

# %%
data.index[0]
# Out:
# '/scratch/merri/jobs/1489812/MYORES-p1-j01-110210_02490688_53caa10e-ac15-4166-9b9d-4b1167f3b9c6_C03_w1_stitched.chs.tif'

# %%
filepaths[0]
# Out:
# 'marcelle/raw-data/pass1/job01/MYORES-p1-j01-110210_02490688_53caa10e-ac15-4166-9b9d-4b1167f3b9c6_EXPORT/MYORES-p1-j01-110210_02490688_53caa10e-ac15-4166-9b9d-4b1167f3b9c6_C03_w1_stitched.chs.tif'

# %%
file_data = map(myo.myores_semantic_filename, filepaths)

# %%
plates = set([f['plate'] for f in file_data])
print plates
# Out:
# set([2490688, 2490689, 2490695, 2490700, 2490701, 2490702, 2490705])

# %% [markdown]
# # Mapping files (from David)
#
# We load the well-to-gene mapping...

# %%
gene_data = [line.rstrip().split(',') for
             line in open("all_annots2.csv", 'r')]
len(gene_data)
# Out:
# 17166

# %% [markdown]
# ... and extract the columns we care about:

# %%
list(enumerate(gene_data[0]))
# Out:
# [(0, 'gene_name'),
#  (1, 'gene_acc'),
#  (2, 'source_plate_barcode'),
#  (3, 'source_plate_label'),
#  (4, 'cell_plate_barcode'),
#  (5, 'cell_plate_label'),
#  (6, 'well'),
#  (7, 'row'),
#  (8, 'column'),
#  (9, 'label'),
#  (10, 'experimental_content_type_name'),
#  (11, 'molecule_design_id')]

# %%
list(enumerate(gene_data[1000]))
# Out:
# [(0, 'Cfdp1'),
#  (1, '23837'),
#  (2, '2490680'),
#  (3, 'Myores_pass1_p1'),
#  (4, '2490704'),
#  (5, 'MY-pass1-j01-MP1-2'),
#  (6, 'L16'),
#  (7, 'L'),
#  (8, '16'),
#  (9, 'sample'),
#  (10, 'SAMPLE'),
#  (11, '10385680')]

# %%
gene_data = [(l[0], l[1], int(l[4]), l[6], l[10]) for l in gene_data[1:]]
# gene name, entrez gene accession, plate, well, control or sample

# %% [markdown]
# And make sure the data we have makes sense:

# %%
print(len(gene_data))
print(gene_data[0])
print(gene_data[3384])
# Out:
# 17165
# ('', '', 2490703, 'C03', 'NEG')
# ('Sdccag3', '68112', 2490695, 'G04', 'SAMPLE')

# %% [markdown]
# The following function will return gene information from the .csv we loaded when given a cluster ID from the Ward clustering.

# %%
def get_cluster_gene_data(cluster_id):
    plate_cluster = [(int(file_data[i]['plate']), file_data[i]['well']) for
                     i in np.flatnonzero(K.labels_ == cluster_id)]
    genes_cluster = [line for line in gene_data
                     if (int(line[2]), line[3]) in plate_cluster]
    return plate_cluster, genes_cluster

# %% [markdown]
# # Cluster sizes

# %%
print(len(K.labels_), len(np.unique(K.labels_)), np.max(K.labels_))
plt.plot(np.bincount(K.labels_))
# Out:
# (1680, 84, 83)

# %% [markdown]
# # Some example clusters

# %%
plate_cluster_1, gene_cluster_1 = get_cluster_gene_data(17)
print(len(plate_cluster_1), len(gene_cluster_1))
gene_cluster_1[:30]
# Out:
# (9, 8)
# [('Atp6v0e', '11974', 2490688, 'I12', 'SAMPLE'),
#  ('Gnaz', '14687', 2490688, 'M06', 'SAMPLE'),
#  ('Map2k5', '23938', 2490689, 'N18', 'SAMPLE'),
#  ('Mrgprb5', '404239', 2490689, 'D11', 'SAMPLE'),
#  ('Nek3', '23954', 2490688, 'K18', 'SAMPLE'),
#  ('Stc1', '20855', 2490688, 'E11', 'SAMPLE'),
#  ('Tmem47', '192216', 2490688, 'C10', 'SAMPLE'),
#  ('Tram1', '72265', 2490688, 'M19', 'SAMPLE')]

# %% [markdown]
# We can use the plate and well numbers to grab the images that were analysed.

# %%
well2file = {}
for info, path in zip(file_data, filepaths):
    well2file[(info['plate'], info['well'])] = path

# %%
well2file.keys()[:5]
# Out:
# [(2490701, 'J20'),
#  (2490700, 'H14'),
#  (2490689, 'I21'),
#  (2490702, 'C22'),
#  (2490701, 'E10')]

# %% [markdown]
# # Grabbing the files from merri

# %%
import mahotas as mh
def grab_image(plate, well):
    f = well2file[(plate, well)]
    f = (f.replace('w1_stitched', 'w?_stitched').
           replace('w2_stitched', 'w?_stitched').
           replace('w3_stitched', 'w?_stitched'))
    sp.check_call(['scp', 'jni@merri.vlsci.unimelb.edu.au:' + f,
                   '.'])
    time.sleep(1)
    try:
        f = f.replace('w?_stitched', 'w1_stitched')
        im = mh.imread(os.path.split(f)[1])
    except ValueError:
        try:
            f = f.replace('w1_stitched', 'w2_stitched')
            im = mh.imread(os.path.split(f)[1])
        except ValueError:
            f = f.replace('w2_stitched', 'w3_stitched')
            im = mh.imread(os.path.split(f)[1])
    return im

# %% [markdown]
# Now we want to look at the images. The below function shows three images side by side, but can be generalised to show a grid of any number of images.

# %%
def show_3ims(ims):
    fig, axes = plt.subplots(1, 3, figsize=(15, 12))
    for im, ax in zip(ims, axes):
        ax.imshow(im)

# %%
keys = [tuple(a[2:4]) for a in
        gene_cluster_1[-3:]]
try:
    ims = [grab_image(p, w) for
           p, w in keys]
except:
    print([well2file[k] for k in keys])
    raise

# %%
show_3ims(ims)

# %% [markdown]
# # Another example
#
# The images look quite similar! Is this a fluke? Let's look at another cluster.

# %%
plate_cluster_2, gene_cluster_2 = get_cluster_gene_data(18)
plate_cluster_2, gene_cluster_2
# Out:
# ([(2490695, 'E06'),
#   (2490695, 'E08'),
#   (2490695, 'E15'),
#   (2490695, 'E17'),
#   (2490695, 'E18'),
#   (2490695, 'F10'),
#   (2490695, 'G21'),
#   (2490695, 'H20'),
#   (2490695, 'I22'),
#   (2490695, 'L09'),
#   (2490695, 'L12'),
#   (2490695, 'L17'),
#   (2490695, 'M05'),
#   (2490695, 'N22'),
#   (2490700, 'C10'),
#   (2490700, 'C16'),
#   (2490700, 'C20'),
#   (2490700, 'D05'),
#   (2490700, 'D11'),
#   (2490700, 'E05'),
#   (2490700, 'E06'),
#   (2490700, 'F04'),
#   (2490700, 'G07'),
#   (2490700, 'G10'),
#   (2490700, 'G12'),
#   (2490700, 'G20'),
#   (2490700, 'H13'),
#   (2490700, 'I18'),
#   (2490700, 'K10'),
#   (2490700, 'K15'),
#   (2490700, 'K19'),
#   (2490700, 'L03'),
#   (2490700, 'L05'),
#   (2490700, 'L07'),
#   (2490700, 'L09'),
#   (2490700, 'L11'),
#   (2490700, 'L12'),
#   (2490700, 'L18'),
#   (2490700, 'M05'),
#   (2490700, 'M11'),
#   (2490700, 'N15'),
#   (2490701, 'D06'),
#   (2490701, 'D07'),
#   (2490701, 'D08'),
#   (2490701, 'E05'),
#   (2490701, 'E13'),
#   (2490701, 'E18'),
#   (2490701, 'F04'),
#   (2490701, 'F06'),
#   (2490701, 'F13'),
#   (2490701, 'F15'),
#   (2490701, 'G07'),
#   (2490701, 'G10'),
#   (2490701, 'G19'),
#   (2490701, 'G20'),
#   (2490701, 'G21'),
#   (2490701, 'H11'),
#   (2490701, 'H13'),
#   (2490701, 'I18'),
#   (2490701, 'K16'),
#   (2490701, 'K19'),
#   (2490701, 'L11'),
#   (2490701, 'L16'),
#   (2490701, 'L20'),
#   (2490701, 'M15'),
#   (2490701, 'M17'),
#   (2490701, 'N13'),
#   (2490701, 'N18'),
#   (2490702, 'C06'),
#   (2490702, 'C10'),
#   (2490702, 'D20'),
#   (2490702, 'F04'),
#   (2490702, 'G07'),
#   (2490702, 'G12'),
#   (2490702, 'G22'),
#   (2490702, 'H06'),
#   (2490702, 'H11'),
#   (2490702, 'H22'),
#   (2490702, 'I05'),
#   (2490702, 'I19'),
#   (2490702, 'K03'),
#   (2490702, 'K08'),
#   (2490702, 'K09'),
#   (2490702, 'K10'),
#   (2490702, 'K21'),
#   (2490702, 'L03'),
#   (2490702, 'L05'),
#   (2490702, 'L07'),
#   (2490702, 'L11'),
#   (2490702, 'L19'),
#   (2490702, 'M04'),
#   (2490702, 'M05'),
#   (2490702, 'M13'),
#   (2490702, 'M15'),
#   (2490702, 'M17'),
#   (2490702, 'N05'),
#   (2490702, 'N07'),
#   (2490702, 'N10'),
#   (2490702, 'N12'),
#   (2490702, 'N13'),
#   (2490702, 'N15'),
#   (2490702, 'N18'),
#   (2490702, 'N19'),
#   (2490702, 'N20'),
#   (2490705, 'C18'),
#   (2490705, 'C22'),
#   (2490705, 'D18'),
#   (2490705, 'E14'),
#   (2490705, 'G07'),
#   (2490705, 'G21'),
#   (2490705, 'G22'),
#   (2490705, 'H03'),
#   (2490705, 'H04'),
#   (2490705, 'I04'),
#   (2490705, 'I08'),
#   (2490705, 'I17'),
#   (2490705, 'J04'),
#   (2490705, 'J09'),
#   (2490705, 'J13'),
#   (2490705, 'J14'),
#   (2490705, 'J19'),
#   (2490705, 'K11'),
#   (2490705, 'L06'),
#   (2490705, 'M03'),
#   (2490705, 'M05'),
#   (2490705, 'N09')],
#  [('', '', 2490700, 'D05', 'NEG'),
#   ('', '', 2490700, 'H13', 'NEG'),
#   ('', '', 2490701, 'H13', 'NEG'),
#   ('', '', 2490702, 'I05', 'SAMPLE'),
#   ('', '', 2490702, 'N20', 'NEG'),
#   ('', '', 2490695, 'N22', 'NEG'),
#   ('1110059G10Rik', '66202', 2490701, 'G19', 'SAMPLE'),
#   ('1700019E19Rik', '76411', 2490702, 'H22', 'SAMPLE'),
#   ('4930503L19Rik', '269033', 2490705, 'H04', 'SAMPLE'),
#   ('A330021E22Rik', '207686', 2490700, 'G10', 'SAMPLE'),
#   ('A330021E22Rik', '207686', 2490701, 'G10', 'SAMPLE'),
#   ('Aacs', '78894', 2490701, 'K16', 'SAMPLE'),
#   ('Aars2', '224805', 2490700, 'N15', 'SAMPLE'),
#   ('Aars2', '224805', 2490702, 'N15', 'SAMPLE'),
#   ('Abhd3', '106861', 2490695, 'E18', 'SAMPLE'),
#   ('Adhfe1', '76187', 2490705, 'G22', 'SAMPLE'),
#   ('Aldh16a1', '69748', 2490701, 'G21', 'SAMPLE'),
#   ('Ankrd1', '107765', 2490700, 'K19', 'SAMPLE'),
#   ('Ankrd1', '107765', 2490701, 'K19', 'SAMPLE'),
#   ('Arhgap10', '78514', 2490705, 'K11', 'SAMPLE'),
#   ('Atp13a5', '268878', 2490700, 'C16', 'SAMPLE'),
#   ('Bmpr1a', '12166', 2490705, 'N09', 'SAMPLE'),
#   ('Cad', '69719', 2490700, 'C20', 'SAMPLE'),
#   ('Ccbl2', '229905', 2490700, 'G20', 'SAMPLE'),
#   ('Ccbl2', '229905', 2490701, 'G20', 'SAMPLE'),
#   ('Cdo1', '12583', 2490702, 'K08', 'SAMPLE'),
#   ('Comtd1', '69156', 2490700, 'L03', 'SAMPLE'),
#   ('Comtd1', '69156', 2490702, 'L03', 'SAMPLE'),
#   ('Coro1c', '23790', 2490702, 'G22', 'SAMPLE'),
#   ('Crb3', '224912', 2490700, 'D11', 'SAMPLE'),
#   ('Creb5', '231991', 2490705, 'J13', 'SAMPLE'),
#   ('Csrp1', '13007', 2490702, 'H06', 'SAMPLE'),
#   ('Cttnbp2nl', '80281', 2490702, 'M13', 'SAMPLE'),
#   ('Cyp39a1', '56050', 2490695, 'E08', 'SAMPLE'),
#   ('Dars', '226414', 2490702, 'K09', 'SAMPLE'),
#   ('Dcaf5', '320808', 2490705, 'L06', 'SAMPLE'),
#   ('Ddx41', '72935', 2490705, 'D18', 'SAMPLE'),
#   ('Depdc5', '277854', 2490705, 'C22', 'SAMPLE'),
#   ('Dnajb12', '56709', 2490701, 'F06', 'SAMPLE'),
#   ('Dok3', '27261', 2490700, 'I18', 'SAMPLE'),
#   ('Dok3', '27261', 2490701, 'I18', 'SAMPLE'),
#   ('E130309D02Rik', '231868', 2490701, 'H11', 'SAMPLE'),
#   ('E130309D02Rik', '231868', 2490702, 'H11', 'SAMPLE'),
#   ('Eif4a2', '13682', 2490700, 'L07', 'SAMPLE'),
#   ('Eif4a2', '13682', 2490702, 'L07', 'SAMPLE'),
#   ('Elfn1', '243312', 2490705, 'M03', 'SAMPLE'),
#   ('Ephx1', '13849', 2490700, 'E06', 'SAMPLE'),
#   ('Ercc1', '13870', 2490705, 'H03', 'SAMPLE'),
#   ('F630043A04Rik', '219114', 2490700, 'G12', 'SAMPLE'),
#   ('F630043A04Rik', '219114', 2490702, 'G12', 'SAMPLE'),
#   ('Fam45a', '67894', 2490700, 'L11', 'SAMPLE'),
#   ('Fam45a', '67894', 2490701, 'L11', 'SAMPLE'),
#   ('Fam45a', '67894', 2490702, 'L11', 'SAMPLE'),
#   ('Gjb1', '14618', 2490700, 'C10', 'SAMPLE'),
#   ('Gjb1', '14618', 2490702, 'C10', 'SAMPLE'),
#   ('Gpr120', '107221', 2490702, 'N07', 'SAMPLE'),
#   ('Gsc', '14836', 2490705, 'G21', 'SAMPLE'),
#   ('Gtf2a1', '83602', 2490695, 'L12', 'SAMPLE'),
#   ('Hddc3', '68695', 2490702, 'D20', 'SAMPLE'),
#   ('Heph', '15203', 2490702, 'K03', 'SAMPLE'),
#   ('Hhex', '15242', 2490705, 'I08', 'SAMPLE'),
#   ('Hps4', '192232', 2490701, 'L16', 'SAMPLE'),
#   ('Hsf2', '15500', 2490705, 'G07', 'SAMPLE'),
#   ('Igfbp6', '16012', 2490700, 'K10', 'SAMPLE'),
#   ('Igfbp6', '16012', 2490702, 'K10', 'SAMPLE'),
#   ('Igsf8', '140559', 2490701, 'N18', 'SAMPLE'),
#   ('Igsf8', '140559', 2490702, 'N18', 'SAMPLE'),
#   ('Ints4', '101861', 2490702, 'M04', 'SAMPLE'),
#   ('Irx5', '54352', 2490701, 'F15', 'SAMPLE'),
#   ('Kctd3', '226823', 2490695, 'E06', 'SAMPLE'),
#   ('Kpna1', '16646', 2490695, 'M05', 'SAMPLE'),
#   ('Lefty2', '320202', 2490701, 'M15', 'SAMPLE'),
#   ('Lefty2', '320202', 2490702, 'M15', 'SAMPLE'),
#   ('Letmd1', '68614', 2490705, 'I17', 'SAMPLE'),
#   ('Lrrtm4', '243499', 2490705, 'J09', 'SAMPLE'),
#   ('Mcoln3', '171166', 2490701, 'M17', 'SAMPLE'),
#   ('Mcoln3', '171166', 2490702, 'M17', 'SAMPLE'),
#   ('Mina', '67014', 2490702, 'K21', 'SAMPLE'),
#   ('Mrps22', '64655', 2490695, 'L17', 'SAMPLE'),
#   ('Msc', '17681', 2490700, 'L09', 'SAMPLE'),
#   ('Olfr93', '258051', 2490701, 'E13', 'SAMPLE'),
#   ('P2rx4', '18438', 2490700, 'L12', 'SAMPLE'),
#   ('Pgpep1', '66522', 2490700, 'G07', 'SAMPLE'),
#   ('Pgpep1', '66522', 2490701, 'G07', 'SAMPLE'),
#   ('Pgpep1', '66522', 2490702, 'G07', 'SAMPLE'),
#   ('Phka2', '110094', 2490695, 'I22', 'SAMPLE'),
#   ('Pou4f2', '18997', 2490695, 'E17', 'SAMPLE'),
#   ('Ppa1', '67895', 2490700, 'F04', 'SAMPLE'),
#   ('Ppa1', '67895', 2490701, 'F04', 'SAMPLE'),
#   ('Ppa1', '67895', 2490702, 'F04', 'SAMPLE'),
#   ('Ptplad1', '57874', 2490702, 'N12', 'SAMPLE'),
#   ('Ptprg', '19270', 2490705, 'E14', 'SAMPLE'),
#   ('Rab1b', '76308', 2490700, 'M05', 'SAMPLE'),
#   ('Rab1b', '76308', 2490702, 'M05', 'SAMPLE'),
#   ('Rasa1', '218397', 2490705, 'J04', 'SAMPLE'),
#   ('Rbm7', '67010', 2490705, 'J14', 'SAMPLE'),
#   ('Rln1', '19773', 2490695, 'H20', 'SAMPLE'),
#   ('Rmnd5a', '68477', 2490701, 'D07', 'SAMPLE'),
#   ('Rxrg', '20183', 2490702, 'C06', 'SAMPLE'),
#   ('Serpina3b', '271047', 2490701, 'E18', 'SAMPLE'),
#   ('Sh3tc1', '231147', 2490695, 'G21', 'SAMPLE'),
#   ('Shisa7', '232813', 2490705, 'M05', 'SAMPLE'),
#   ('Slc12a7', '20499', 2490705, 'J19', 'SAMPLE'),
#   ('Slc22a20', '381203', 2490700, 'K15', 'SAMPLE'),
#   ('Slc35f1', '215085', 2490701, 'L20', 'SAMPLE'),
#   ('Snai3', '30927', 2490702, 'I19', 'SAMPLE'),
#   ('Spdef', '30051', 2490702, 'N05', 'SAMPLE'),
#   ('Stambpl1', '76630', 2490702, 'N10', 'SAMPLE'),
#   ('Tbcel', '272589', 2490701, 'F13', 'SAMPLE'),
#   ('Timp3', '21859', 2490702, 'L19', 'SAMPLE'),
#   ('Tipin', '66131', 2490701, 'D08', 'SAMPLE'),
#   ('Tmem165', '21982', 2490700, 'E05', 'SAMPLE'),
#   ('Tmem165', '21982', 2490701, 'E05', 'SAMPLE'),
#   ('Tnf', '21926', 2490695, 'F10', 'SAMPLE'),
#   ('Tspan5', '56224', 2490701, 'D06', 'SAMPLE'),
#   ('Tulp4', '68842', 2490701, 'N13', 'SAMPLE'),
#   ('Tulp4', '68842', 2490702, 'N13', 'SAMPLE'),
#   ('Ubqln1', '56085', 2490695, 'L09', 'SAMPLE'),
#   ('Usp38', '74841', 2490705, 'C18', 'SAMPLE'),
#   ('Vcam1', '22329', 2490695, 'E15', 'SAMPLE'),
#   ('Vps37d', '194309', 2490705, 'I04', 'SAMPLE'),
#   ('Wbscr16', '94254', 2490702, 'N19', 'SAMPLE'),
#   ('Wdr45', '54636', 2490700, 'M11', 'SAMPLE'),
#   ('Wnt6', '22420', 2490700, 'L18', 'SAMPLE'),
#   ('Zcchc5', '213436', 2490700, 'L05', 'SAMPLE'),
#   ('Zcchc5', '213436', 2490702, 'L05', 'SAMPLE')])

# %%
keys = [tuple(a[2:4]) for a in
        gene_cluster_2[-3:]]
try:
    ims = [grab_image(p, w) for
           p, w in keys]
except:
    print([well2file[k] for k in keys])
    raise

# %%
show_3ims(ims)

# %% [markdown]
# # To be continued...
#
# ## some sanity checks
#
#  - distance between feature vectors of same gene should be much closer than random pairs
#  - distance between positive controls and between negative controls should be much closer than between pairs of the two
#  - plates and well location should not cluster together. If they do, need to correct for this
#
# ## Clustering of entire dataset
#
#  - a lot of "bad" that I need to investigate.
#  - modifications to run on the cluster are *done*.
#
# ## Gene Ontology enrichment of clusters
#
#  - can we associate specific GO functions with the clusters?
#
# ## Look at extreme examples of certain features
#
#  - for example, what do images on either extreme of the nn-angle feature look like?
